# %%
import tempfile
tempfile.tempdir = 'G:\\VSC_TEMP'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from time import time
warnings.filterwarnings ('ignore')

pd.set_option ('display.float_format', lambda x: '%.3f' % x)
plt.rcParams ["figure.figsize"] = (10,6) 

#READING DATASET & ADJSUTING COLUMNS
readTrainFile = pd.read_csv ('KDDCup99_full.txt')
organisedFile = readTrainFile.copy()
columns = (['duration' #Duration of connection in seconds
            ,'protocolType' #Protocol used for the connection (ICMP, UDP, TCP, etc.)
            ,'service' #Destination port that is mapped to a service (HTTP, FTP, HTTPS, etc.)
            ,'flag' #Normal or error status flag of connection (SF, S0 & REJ)
            ,'sourceByte' #Number of data, in bytes, from source to destination
            ,'destinationByte' #Number of data bytes from destination to source
            ,'land' #'1' represents if the connection is from/to the same host/port; else '0'
            ,'wrongFragment' #Number of 'wrong' fragments (values 0,1,3)
            ,'urgent' #Number of urgent packets
            ,'hot' #Number of 'hot' indicators (bro-ids feature)
            ,'numberFailedLogins' #Number of failed login attempts
            ,'loggedIn' #'1' indicates if sucessfully logged, else '0'
            ,'numberCompromised' #Number of 'compromised' conditions
            ,'rootShell' #'1' indicates if root shell is obtained, otherwise '0'
            ,'suAttempted' #'1' indicates if "Super User Root" command was attempted, otherwise '0'
            ,'numRoot' #Number of root acesses 
            ,'numberFileCreations' #Number of file creation operations
            ,'numberShells' #Number of shell prompts
            ,'numberAccessFiles' #Number of operations on the acess control files
            ,'numberOutboundCommands' #Number of outbound commands within an ftp session
            ,'isHotLogin' #'1' is the login belongs to a 'hot' list (e.g. root, admin); else 0
            ,'isGuestLogin' #'1' is if the login is a 'guest' login (e.g. guest, anonymous, etc.); else 0
            ,'count' #The number of connections to the same host as current connections in past two seconds
            ,'srvCount' #The number of connections tot he same service as the curent connection in the past two seconds
            ,'serrorRate' #The percetage(%) of connections that have 'SYN' errors
            ,'srvSerrorRate' #The percetage(%) of connections that have 'SYN' errors
            ,'rerrorRate' #The percetage(%) of connections that have 'REJ' errors
            ,'srvRerrorRate' #The percetage(%) of connections that have 'REJ' errors
            ,'sameSrvRate' #The percentage(%) of connections to the same services
            ,'diffSrvRate' #The percentage(%) of connections to different services
            ,'srvDiffHostRate' #The percentage(%) of connections to different hosts
            ,'destinationHostCount' #The count of the connections that have the same destination host
            ,'destinationHostSrvCount' #The count of the connections that have the same destination host and using the same service
            ,'destinationHostSameSrvCount' #The percentage(%) of connections having the same destination port and using the same service
            ,'destinationHostDiffSrvCount' #The percentage(%) of different services on the current host
            ,'destinationHostSameSourcePortRate' #The percentage(%) of connections to the current host having the same source port
            ,'destinationHostSrvDifferentHostRate' #The percentage(%) of connections to the same service coming from a different host
            ,'destinationHostSerrorRate' #The percentage(%) of connections to the current host that have an S0 error
            ,'destinationHostSrvSerrorRate' #The percentage(%) of connections to the current host and specified service that have an S0 error
            ,'destinationHostRerrorRate' #The percentage(%) of connections to the current host that have an RST error
            ,'destinationHostSrvRerrorRate' #The percentage(%) of connections to the  current host and specified service
            ,'attack']) #Classifying whether the attack was considered normal or an anomaly 
organisedFile.columns = columns
organisedFile.head(10)
organisedFile.info()
organisedFile.describe().T

#DATA CLEANING
organisedFile.isnull().sum()
def uniqueValues(organisedFile, columns):
    for columnName in columns:
        print(f"column: {columnName}\n{'-'*30}")
        uniqueValues = organisedFile[columnName].unique()
        valueCounts = organisedFile[columnName].value_counts()
        print(f"Unique Values ({len(uniqueValues)}): {uniqueValues}\n")
        print(f"Value Counts:\n{valueCounts}\n{'='*40}\n")
catFeatures = organisedFile.select_dtypes(include='object').columns
uniqueValues(organisedFile, catFeatures)

organisedFile.duplicated().sum()

organisedFile.shape
plt.figure(figsize=(20,40))
organisedFile.plot(kind='box', subplots=True, layout=(8,5), figsize=(20,40))
plt.show()
attackClassifier = []
for i in organisedFile.attack:
    if i == 'normal':
        attackClassifier.append("normal")
    else:
        attackClassifier.append("attack")
organisedFile['attack'] = attackClassifier
organisedFile['attack'].unique()\

#PREPROCESSING
catFeatures = organisedFile.select_dtypes(include = 'object').columns
catFeatures

from sklearn import preprocessing
labelEncoder = preprocessing.LabelEncoder()
clm = ['protocolType', 'service', 'flag', 'attack']
for x in clm:
    organisedFile[x] = labelEncoder.fit_transform(organisedFile[x])

#TRAIN-TEST-SPLIT
from sklearn.model_selection import train_test_split

x = organisedFile.drop(["attack"], axis=1)
y = organisedFile["attack"]

xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.1, random_state=43)

trainIndex = xTrain.columns
trainIndex

#FEATURE ENGINEERING
from sklearn.feature_selection import mutual_info_classif
mutalInfo = mutual_info_classif(xTrain, yTrain)
mutalInfo = pd.Series(mutalInfo)
mutalInfo.index = trainIndex
mutalInfo.sort_values(ascending=False)

mutalInfo.sort_values(ascending=False).plot.bar(figsize=(20, 5));

#FEATURE SELECTION
from sklearn.feature_selection import SelectKBest
selectFeatures = SelectKBest(mutual_info_classif, k = 30)
selectFeatures.fit(xTrain, yTrain)
trainIndex[selectFeatures.get_support()]

#TOP FEATURES FOR TRAINING
columns = ['duration','protocolType','service','flag','sourceByte','destinationByte','wrongFragment','hot','loggedIn','numberCompromised','count','srvCount','serrorRate','srvSerrorRate','rerrorRate']
xTrain = xTrain[columns]
xTest = xTest[columns]

#SCALNG
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

#Transform is done to prevent data leakage
xTrain = scaler.fit_transform(xTrain)
xTest = scaler.fit_transform(xTest)

#MODEL BUILD
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score

def evaluationMetric (model, xTrain, yTrain, xTest, yTest):
    yTrainPrediction = model.predict(xTrain)
    yPrediction = model.predict(xTest)

    print ("Test Set")
    print(confusion_matrix(yTest, yPrediction))
    print(classification_report(yTest, yPrediction, digits=6))
    print()
    print("Train Set")
    print(confusion_matrix(yTrain, yTrainPrediction))
    print(classification_report(yTrain, yTrainPrediction, digits=6))

#HYPERPARAMETER TUNING
from sklearn.model_selection import GridSearchCV
from  sklearn.model_selection import RepeatedStratifiedKFold


#K-Means (Check Parameters)
#SOURCE: https://www.kaggle.com/code/diegohurtadoo/customer-segmentation-kmeans-parameter-tuning#3.4--KMeans-
from sklearn.cluster import KMeans
n_clusters = [2]
init = ['k-means++', 'random']
n_init = [5, 10]
max_iter = [300, 350, 400]
tol = [0.001, 0.01]
algorithm = ['auto', 'full', 'elkan', 'lloyd']
random_state = [42]

kmCV = RepeatedStratifiedKFold(n_splits=5, n_repeats=2, random_state=42)

kmModel = KMeans(random_state=42)
kmGrid = dict(n_clusters=n_clusters, init=init, n_init=n_init, max_iter=max_iter, tol=tol, algorithm=algorithm, random_state=random_state)
gridSearchKM = GridSearchCV(estimator=kmModel, param_grid=kmGrid, n_jobs=-1, cv=kmCV, verbose=1, scoring='accuracy', error_score=0)
start = time()
gridResultKM = gridSearchKM.fit(xTrain, yTrain)
end = time()
print("Best: %f using %s" % (gridResultKM.best_score_, gridResultKM.best_params_))
means = gridResultKM.cv_results_['mean_test_score']
stds = gridResultKM.cv_results_['std_test_score']
params = gridResultKM.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
result = end - start
print('%.3f seconds' % result)
print("K-Means Hyperparameter Tuning Done!")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898430 entries, 0 to 4898429
# Data columns (total 42 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   duration                             int64
#  1   protocolType                         object
#  2   service                              object
#  3   flag                                 object
#  4   sourceByte                           int64
#  5   destinationByte                      int64
#  6   land                                 int64
#  7   wrongFragment                        int64
#  8   urgent                               int64
#  9   hot                                  int64
#  10  numberFailedLogins                   int64
#  11  loggedIn                             int64
#  12  numberCompromised                    int64
#  13  rootShell                            int64
#  14  suAttempted                          int64
#  15  numRoot                              int64
#  16  numberFileCreations                  int64
#  17  numberShells                         int64
#  18  numberAccessFiles                    int64
#  19  numberOutboundCommands               int64
#  20  isHotLogin                           int64
#  21  isGuestLogin                         int64
#  22  count                                int64
#  23  srvCount                             int64
#  24  serrorRate                           float64
#  25  srvSerrorRate                        float64
#  26  rerrorRate                           float64
#  27  srvRerrorRate                        float64
#  28  sameSrvRate                          float64
#  29  diffSrvRate                          float64
#  30  srvDiffHostRate                      float64
#  31  destinationHostCount                 int64
#  32  destinationHostSrvCount              int64
#  33  destinationHostSameSrvCount          float64
#  34  destinationHostDiffSrvCount          float64
#  35  destinationHostSameSourcePortRate    float64
#  36  destinationHostSrvDifferentHostRate  float64
#  37  destinationHostSerrorRate            float64
#  38  destinationHostSrvSerrorRate         float64
#  39  destinationHostRerrorRate            float64
#  40  destinationHostSrvRerrorRate         float64
#  41  attack                               object
# dtypes: float64(15), int64(23), object(4)
# memory usage: 1.5+ GB
# column: protocolType
# ------------------------------
# Unique Values (3): ['tcp' 'udp' 'icmp']
#
# Value Counts:
# protocolType
# icmp    2833545
# tcp     1870597
# udp      194288
# Name: count, dtype: int64
# ========================================
#
# column: service
# ------------------------------
# Unique Values (70): ['http' 'smtp' 'domain_u' 'auth' 'finger' 'telnet' 'eco_i' 'ftp' 'ntp_u'
#  'ecr_i' 'other' 'urp_i' 'private' 'pop_3' 'ftp_data' 'netstat' 'daytime'
#  'ssh' 'echo' 'time' 'name' 'whois' 'domain' 'mtp' 'gopher' 'remote_job'
#  'rje' 'ctf' 'supdup' 'link' 'systat' 'discard' 'X11' 'shell' 'login'
#  'imap4' 'nntp' 'uucp' 'pm_dump' 'IRC' 'Z39_50' 'netbios_dgm' 'ldap'
#  'sunrpc' 'courier' 'exec' 'bgp' 'csnet_ns' 'http_443' 'klogin' 'printer'
#  'netbios_ssn' 'pop_2' 'nnsp' 'efs' 'hostnames' 'uucp_path' 'sql_net'
#  'vmnet' 'iso_tsap' 'netbios_ns' 'kshell' 'urh_i' 'http_2784' 'harvest'
#  'aol' 'tftp_u' 'http_8001' 'tim_i' 'red_i']
#
# Value Counts:
# service
# ecr_i        2811660
# private      1100831
# http          623090
# smtp           96554
# other          72653
#               ...
# tftp_u             3
# harvest            2
# aol                2
# http_8001          2
# http_2784          1
# Name: count, Length: 70, dtype: int64
# ========================================
#
# column: flag
# ------------------------------
# Unique Values (11): ['SF' 'S2' 'S1' 'S3' 'OTH' 'REJ' 'RSTO' 'S0' 'RSTR' 'RSTOS0' 'SH']
#
# Value Counts:
# flag
# SF        3744327
# S0         869829
# REJ        268874
# RSTR         8094
# RSTO         5344
# SH           1040
# S1            532
# S2            161
# RSTOS0        122
# OTH            57
# S3             50
# Name: count, dtype: int64
# ========================================
#
# column: attack
# ------------------------------
# Unique Values (23): ['normal' 'buffer_overflow' 'loadmodule' 'perl' 'neptune' 'smurf'
#  'guess_passwd' 'pod' 'teardrop' 'portsweep' 'ipsweep' 'land' 'ftp_write'
#  'back' 'imap' 'satan' 'phf' 'nmap' 'multihop' 'warezmaster' 'warezclient'
#  'spy' 'rootkit']
#
# Value Counts:
# attack
# smurf              2807886
# neptune            1072017
# normal              972780
# satan                15892
# ipsweep              12481
# portsweep            10413
# nmap                  2316
# back                  2203
# warezclient           1020
# teardrop               979
# pod                    264
# guess_passwd            53
# buffer_overflow         30
# land                    21
# warezmaster             20
# imap                    12
# rootkit                 10
# loadmodule               9
# ftp_write                8
# multihop                 7
# phf                      4
# perl                     3
# spy                      2
# Name: count, dtype: int64
# ========================================
# Fitting 10 folds for each of 480 candidates, totalling 4800 fits
# Best: 0.801294 using {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'auto', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.000000 (0.000000) with: {'algorithm': 'full', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.380093 (0.319799) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.380093 (0.319799) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.380093 (0.319799) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.380093 (0.319799) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.482551 (0.281628) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.482551 (0.281628) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.455948 (0.311208) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.455948 (0.311208) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.360577 (0.264790) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.381934 (0.244340) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.380093 (0.319799) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.380093 (0.319799) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.380093 (0.319799) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.380093 (0.319799) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.482551 (0.281628) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.482551 (0.281628) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.455948 (0.311208) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.455948 (0.311208) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.360577 (0.264790) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.381934 (0.244340) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.384740 (0.224899) with: {'algorithm': 'elkan', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# ...
# 0.455948 (0.311208) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.455948 (0.311208) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.360577 (0.264790) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.381934 (0.244340) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.384740 (0.224899) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.384740 (0.224899) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.384740 (0.224899) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.384740 (0.224899) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.380093 (0.319799) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.380093 (0.319799) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.380093 (0.319799) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.380093 (0.319799) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.482551 (0.281628) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.482551 (0.281628) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.455948 (0.311208) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.455948 (0.311208) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.360577 (0.264790) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.381934 (0.244340) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.384740 (0.224899) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.384740 (0.224899) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.384740 (0.224899) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.384740 (0.224899) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.380093 (0.319799) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.380093 (0.319799) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.380093 (0.319799) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.380093 (0.319799) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.482551 (0.281628) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.482551 (0.281628) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.455948 (0.311208) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.455948 (0.311208) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.360577 (0.264790) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.342934 (0.281639) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.381934 (0.244340) with: {'algorithm': 'lloyd', 'init': 'k-means++', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.198008 (0.183192) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.198008 (0.183192) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.211203 (0.181064) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.211203 (0.181064) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.430956 (0.243136) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.430954 (0.243138) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.359015 (0.240481) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.359013 (0.240482) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.200578 (0.215751) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.200578 (0.215750) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.202538 (0.219590) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.202538 (0.219590) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.215620 (0.230926) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.215620 (0.230925) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.356020 (0.259143) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.356018 (0.259143) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 300, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.198008 (0.183192) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.198008 (0.183192) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.211203 (0.181064) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.211203 (0.181064) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.430956 (0.243136) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.430954 (0.243138) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.359015 (0.240481) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.359013 (0.240482) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.200578 (0.215751) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.200578 (0.215750) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.202538 (0.219590) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.202538 (0.219590) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.215620 (0.230926) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.215620 (0.230925) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.356020 (0.259143) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.356018 (0.259143) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 350, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.801294 (0.000000) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 1, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.198008 (0.183192) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.198008 (0.183192) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.211203 (0.181064) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.211203 (0.181064) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 3, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.430956 (0.243136) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.430954 (0.243138) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.359015 (0.240481) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.359013 (0.240482) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 5, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.200578 (0.215751) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.200578 (0.215750) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.202538 (0.219590) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.202538 (0.219590) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 7, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 0.215620 (0.230926) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.001}
# 0.215620 (0.230925) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 5, 'random_state': 42, 'tol': 0.01}
# 0.356020 (0.259143) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.001}
# 0.356018 (0.259143) with: {'algorithm': 'lloyd', 'init': 'random', 'max_iter': 400, 'n_clusters': 9, 'n_init': 10, 'random_state': 42, 'tol': 0.01}
# 7378.745 seconds
# K-Means Hyperparameter Tuning Done!
